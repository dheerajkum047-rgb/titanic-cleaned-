# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cleaned_titanic.csv")
df.head()
# Out:
#     Name   Age  Gender Class  Marks  Attendance     City
# 0  Rahul  11.0    Male   BCA   82.0   85.000000    Delhi
# 1  Priya   1.0  Female   BCA   82.0   88.000000   Mumbai
# 2   Amit  11.0    Male   BBA   82.0   72.666667  Kolkata
# 3  Sneha  21.0  Female   BCA   82.0   45.000000  Chennai

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           0
# Gender        0
# Class         0
# Marks         0
# Attendance    0
# City          0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Marks'].fillna(df['Marks'].mean(), inplace=True)
df['Attendance'].fillna(df['Attendance'].mean(), inplace=True)
# Out:
# C:\Users\JAY CHANDRA PAL\AppData\Local\Temp\ipykernel_6580\249434254.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# C:\Users\JAY CHANDRA PAL\AppData\Local\Temp\ipykernel_6580\249434254.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(df['Marks'].mean(), inplace=True)
# C:\Users\JAY CHANDRA PAL\AppData\Local\Temp\ipykernel_6580\249434254.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].fillna(df['Attendance'].mean(), inplace=True)

# %%
df['City'].fillna(df['City'].mode()[0], inplace=True)
# Out:
# C:\Users\JAY CHANDRA PAL\AppData\Local\Temp\ipykernel_6580\1488218936.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['City'].fillna(df['City'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           0
# Gender        0
# Class         0
# Marks         0
# Attendance    0
# City          0
# dtype: int64

# %%
df.to_csv("cleaned_titanic.csv", index=False)
